# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.coordinates as coord
import astropy.units as u

# %%
(1*1e-3*u.mas/u.yr*761*u.kpc/u.deg/180*np.pi).to(u.km/u.s)
# Out:
# <Quantity 3.60749802 km / s>

# %%
3.607*np.cos(77.5*u.deg)#*np.sin(37.5*u.deg)
# Out:
# <Quantity 0.78069769>

# %%
plt.errorbar(173.16,-138.528,xerr=22,yerr=18.759,fmt='o',label='Gaia EDR3')
plt.errorbar(169,-104.98,xerr=42.208,yerr=33.91,fmt='o',label='Gaia DR3')
plt.errorbar(234.49,-205.627,xerr=65,yerr=54.11,fmt='o',label='Gaia DR2')
plt.errorbar(162.34,-115.44,xerr=46.9,yerr=43.29,fmt='o',label='HST')
plt.errorbar(176.77,-137.085,xerr=39.68,yerr=39.68,fmt='o',label='DR2+HST')
plt.errorbar(123.74,-72.9,xerr=0,yerr=0,fmt='o',label='vdM12')
plt.scatter(140,-77.92,marker='x',label='Vtan=0',color='k')
plt.xlim(300,0)
plt.ylim(-300,0)
plt.xlabel(r'$v_\alpha$ [km/s]',fontsize=16)
plt.ylabel(r'$v_\delta$ [km/s]',fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=14)
