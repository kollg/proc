# %%
import readgadget as rg 
import matplotlib.gridspec as gridspec
from matplotlib import style
import numpy as np
import matplotlib.pyplot as plt
import imageio
from scipy.spatial import cKDTree
from joblib import Parallel, delayed
from matplotlib.animation import FuncAnimation, PillowWriter
from IPython.display import HTML
from scipy.stats import gaussian_kde

# %%
def cent_h(X):

    
    # 构建 KD 树
    tree = cKDTree(X)  

    # 为每个点查询最近的30个邻居点
    dist, ind = tree.query(X, k=60)  

    # 计算局部密度
    epsilon = 1e-5
    rho = 1 / (dist + epsilon).sum(axis=1)

    # 密度最大值点的索引
    densest_idx = np.argmax(rho)

    return X[densest_idx]

def read(runpath ,i):
    snapfname = runpath + 'snapshot_' + str(i).zfill(3) 
    phalo = rg.readsnap(snapfname, 'pos', 'dm')
    idhalo = rg.readsnap(snapfname, 'pid', 'dm')
    pdisk = rg.readsnap(snapfname, 'pos', 'disk')
    pbulge = rg.readsnap(snapfname, 'pos', 'bulge')
    idisk = rg.readsnap(snapfname, 'pid', 'disk')
    ibulge = rg.readsnap(snapfname, 'pid', 'bulge')
    vbulge = rg.readsnap(snapfname, 'vel', 'bulge')
    
    '''pmw_halo = phalo[(idhalo > 0) & (idhalo <= 1000000/2)]
    pm31_halo = phalo[(idhalo > 1000000/2) & (idhalo <= 2500000/2)]
    plmc_halo = phalo[(idhalo > 1250000) & (idhalo <= 1300000)]
    
    pmw_disk = pdisk[(idisk > 1300000) & (idisk <= 1650000)]
    pmw_bulge = pbulge[(ibulge > 2250000) & (ibulge <= 2300000)]
    
    pm31_disk = pdisk[(idisk > 1650000) & (idisk <= 2250000)]    
    pm31_bulge = pbulge[(ibulge > 2300000) & (ibulge <= 2395000)]
    vm31_bulge = vbulge[(ibulge > 2300000) & (ibulge <= 2395000)]
    
    plmc_bulge = pbulge[(ibulge > 2395000) & (ibulge <= 2420000)]
    vlmc_bulge = vbulge[(ibulge > 2395000) & (ibulge <= 2420000)]#light lmc'''
    
    pmw_halo = phalo[(idhalo > 0) & (idhalo <= 1000000/2)]
    pm31_halo = phalo[(idhalo > 1000000/2) & (idhalo <= 2500000/2)]
    plmc_halo = phalo[(idhalo > 1250000) & (idhalo <= 1320000)]
    
    pmw_disk = pdisk[(idisk > 1320000) & (idisk <= 1670000)]
    pmw_bulge = pbulge[(ibulge > 2270000) & (ibulge <= 2320000)]
    
    pm31_disk = pdisk[(idisk > 1670000) & (idisk <= 2270000)]    
    pm31_bulge = pbulge[(ibulge > 2320000) & (ibulge <= 2415000)]
    vm31_bulge = vbulge[(ibulge > 2320000) & (ibulge <= 2415000)]
    
    plmc_bulge = pbulge[(ibulge > 2415000) & (ibulge <= 2450000)]
    vlmc_bulge = vbulge[(ibulge > 2415000) & (ibulge <= 2450000)]#mid lmc'''
    
    
    '''pmw_halo = phalo[(idhalo > 0) & (idhalo <= 1000000/2)]
    pm31_halo = phalo[(idhalo > 1000000/2) & (idhalo <= 2500000/2)]
    plmc_halo = phalo[(idhalo > 1280000) & (idhalo <= 1350000)]
    
    pmw_disk = pdisk[(idisk > 1350000) & (idisk <= 1700000)]
    pmw_bulge = pbulge[(ibulge > 2300000) & (ibulge <= 2350000)]
    
    pm31_disk = pdisk[(idisk > 1700000) & (idisk <= 2300000)]    
    pm31_bulge = pbulge[(ibulge > 2350000) & (ibulge <= 2445000)]
    vm31_bulge = vbulge[(ibulge > 2350000) & (ibulge <= 2445000)]
    
    plmc_bulge = pbulge[(ibulge > 2445000) & (ibulge <= 2495000)]
    vlmc_bulge = vbulge[(ibulge > 2445000) & (ibulge <= 2495000)]#heavy lmc'''
    
    cent_mw = cent_h(pmw_bulge)
    print(cent_mw)
    cent_m31 = cent_h(pm31_bulge)
    print(cent_m31)
    cent_lmc = cent_h(plmc_bulge)
    print(cent_lmc)
    #pstar = pm31_bulge - cent_m31.reshape((1, 3))
    #rr2 = ((pstar**2).sum(-1))**0.5
    #vgal2 = np.mean(vm31_bulge[rr2 <= 5., :], axis=0)
    #print(vgal2)
    r_mw_m31= cent_m31-cent_mw
    r_mw_lmc = cent_lmc-cent_mw
    r_m31_lmc = cent_lmc-cent_m31
    posMW = np.r_[pmw_disk-cent_mw]    
    posM31 = np.r_[pm31_disk-cent_mw]
    posLMC = np.r_[plmc_halo-cent_mw]
    posdm_MW = np.r_[pmw_halo-cent_mw]
    posdm_M31 = np.r_[pm31_halo-cent_mw]
    return posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc


def create_density_map(pos, xlim, ylim, bins=100):
    H, xedges, yedges = np.histogram2d(pos[:, 0], pos[:, 1], bins=bins, range=[xlim, ylim])
    H = H.T  # Transpose to match the orientation of the plot
    return H, xedges, yedges

# %%
runpath = '/home/guozx/M31/Output/low_res/DR3_lmc/'
i =0
posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc = read(runpath,i)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# 绘制 x-y 图
axs[0, 0].scatter(r_mw_m31[0], r_mw_m31[1], c='r', label='M31')
axs[0, 0].scatter(0, 0, c='b', label='MW')
axs[0, 0].scatter(r_mw_lmc[0], r_mw_lmc[1], c='g', label='LMC')
axs[0, 0].set_xlabel('x[kpc]')
axs[0, 0].set_ylabel('y[kpc]')
axs[0, 0].legend()
axs[0, 0].set_xlim(-500, 500)
axs[0, 0].set_ylim(-500, 500)

# 绘制 x-z 图
axs[1, 0].scatter(r_mw_m31[0], r_mw_m31[2], c='r', label='M31')
axs[1, 0].scatter(0, 0, c='b', label='MW')
axs[1, 0].scatter(r_mw_lmc[0], r_mw_lmc[2], c='g', label='LMC')
axs[1, 0].set_xlabel('x[kpc]')
axs[1, 0].set_ylabel('z[kpc]')
axs[1, 0].legend()
axs[1, 0].set_xlim(-500, 500)
axs[1, 0].set_ylim(-500, 500)

# 绘制 y-z 图
axs[1, 1].scatter(r_mw_m31[1], r_mw_m31[2], c='r', label='M31')
axs[1, 1].scatter(0, 0, c='b', label='MW')
axs[1, 1].scatter(r_mw_lmc[1], r_mw_lmc[2], c='g', label='LMC')
axs[1, 1].set_xlabel('y[kpc]')
axs[1, 1].set_ylabel('z[kpc]')
axs[1, 1].legend()
axs[1, 1].set_xlim(-500, 500)
axs[1, 1].set_ylim(-500, 500)

# 绘制 r 随时间变化的图
'''axs[0, 1].plot(time_values[:frame+1], r_values[:frame+1], 'g-')
axs[0, 1].set_xlabel('Time')
axs[0, 1].set_ylabel('r')
axs[0, 1].set_title('r vs Time')
axs[0, 1].set_xlim(0, 10)
axs[0, 1].set_ylim(0, 800)'''

print(posMW[:, [0, 1]].shape)
# Out:
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-0.0021618  -0.00543999  0.00177899]
# [-375.13028  605.5266  -278.83322]
# [ -0.61487365 -41.02209    -26.83447   ]
# (350000, 2)

# %%
r0 = np.array([-375.1316149740847,605.5277209737903,-278.83597703631733]) 
v0 = np.array([37.53564320437491,-114.3816276001235,15.117831344570334])#dr3
x_COM = r0/np.linalg.norm(r0)
z_COM = -np.cross(r0,v0)/np.linalg.norm(np.cross(r0,v0))
y_COM = -np.cross(x_COM,z_COM)
print(x_COM,y_COM,z_COM)
#坐标变化的矩阵
A = np.array([x_COM,y_COM,z_COM])
A = A.T
frames = np.arange(0, 500, 5)
# 并行读取数据
results = Parallel(n_jobs=10)(delayed(read)(runpath, i) for i in frames)
rm31 = np.array([result[3] for result in results])
rlmc = np.array([result[4] for result in results])
rmw = np.zeros_like(rm31)
COM = 1.5/(1+1.5+0.14)*rm31+0.14/(1+1.5+0.14)*rlmc


rCOM_mw = np.dot(rmw-COM, A)
rCOM_m31 = np.dot(rm31-COM, A)
rCOM_lmc = np.dot(rlmc-COM, A)
# Out:
# [-0.49040497  0.79159899 -0.36451886] [0.46221467 0.59084539 0.66125587] [ 0.73882377  0.1557972  -0.65564218]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE PositionsReturning DM    Positions
#
# Returning DM    Positions
# Returning DM    Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Positions
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [-0.0021618  -0.00543999  0.00177899]
# Returning BULGE Velocities
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-0.24279194 -2.3552134  -0.8453931 ]
# [ -6.223299  -19.91488     2.6808846]
# [ -3.932713  -15.275603    0.9135312]
# [ 0.03325323 -0.66739184 -0.47317925]
# [ -3.0675495  -12.486378     0.03164109]
# [-0.7951699 -4.754124  -0.9829924]
# [-2.1390166 -9.856515  -0.5366774]
# [ -4.978184  -17.742336    1.7396134]
# [-1.396788  -7.2963195 -0.8860831]
# [-375.13028  605.5266  -278.83322]
# [-367.86285  582.7901  -275.97025]
# [ -0.61487365 -41.02209    -26.83447   ]
# [-340.25577  499.76367 -264.24164]
# [-348.19574  522.98096 -267.62866]
# Returning DM    Positions
# [-371.59595  594.05    -277.3235 ]
# [-363.75024  570.239   -274.41455]
# Returning DM    Particle IDs
# [-352.51016  535.66296 -269.29126]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [-356.2502   547.40674 -271.07773]
# Returning BULGE Velocities
# [-360.04318  558.74194 -272.68353]
# [-344.3739   511.24557 -265.86163]
# [-13.438359 -71.7292    18.063639]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-40.4299   -90.866234 138.12894 ]
# [-34.72623  -91.178566 112.153694]
# [ -7.3387594 -59.252842   -4.617857 ]
# Returning DM    Positions
# [-19.049923 -80.23725   41.66704 ]
# [-31.087938 -89.9203    95.89063 ]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-27.518549 -88.01297   79.42436 ]
# Returning DM    Positions
# [-23.52876 -85.01238  61.40875]
# [-37.687416 -91.39283  125.66957 ]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -7.3114934 -22.276588    3.6740818]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -8.7731695 -24.287086    4.8070664]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning BULGE Velocities
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning BULGE Velocities
# [-10.067177  -26.08567     6.0256658]
# [-11.716093  -28.177786    7.0123444]
# [-13.268661 -29.854193   8.12748 ]
# [-16.53762  -32.957794  10.462982]
# [-18.258581 -34.25113   11.653464]
# [-20.152193 -35.06346   12.639193]
# [-22.24878  -36.481636  13.793681]
# [-14.6652   -31.481668   9.348274]
# [-336.152    487.72736 -262.42206]
# [-331.6114   474.71292 -260.32172]
# [-42.897964 -89.97346  149.48187 ]
# [-327.48804  462.72925 -258.56122]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-45.552597 -88.54285  160.5663  ]
# Returning DM    Positions
# [-323.22205  450.62292 -256.60532]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-319.01337  438.48196 -254.60551]
# [-47.85601 -86.80804 169.75264]
# [-309.68942  412.56778 -250.16695]
# [-305.16797  400.16473 -248.09657]
# Returning DM    Positions
# Returning DM    Particle IDs
# [-300.66467  387.75674 -245.91179]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [-295.76413  373.83472 -243.46811]
# Returning BULGE Velocities
# [-314.41675  425.03735 -252.24454]
# [-49.683735 -84.62538  177.96222 ]
# [-24.494732 -37.101112  14.832884]
# [-51.634937 -82.24962  185.22472 ]
# Returning DM    Positions
# [-55.00337  -75.841896 197.86012 ]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# [-56.490536 -72.30927  202.44052 ]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# [-57.687836 -68.75801  206.14653 ]
# Returning BULGE Positions
# [-59.088684 -64.572296 209.23868 ]
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-26.714779 -37.81658   15.729109]
# [-53.467724 -79.021484 192.37117 ]
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DISK  Positions
# Returning DM    Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Positions
# Returning DM    Particle IDs
# [-29.070854 -38.319405  16.642683]
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-31.592209 -39.04602   17.612398]
# [-34.073105 -39.05253   18.433935]
# [-36.602062 -39.35561   19.255758]
# [-39.665386 -39.301258  20.010883]
# [-291.20984  361.24384 -241.05276]
# [-42.461494 -38.92988   20.642265]
# [-49.108654 -37.539375  21.751163]
# [-45.81401  -38.252396  21.344978]
# [-286.4106   348.3037  -238.39873]
# [-60.172897 -60.57452  211.33298 ]
# [-281.68738  335.54974 -235.88075]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-61.453667 -56.463623 212.35233 ]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-271.4648   307.9437  -230.47583]
# [-276.55933  321.18765 -233.1192 ]
# [-62.14725 -52.24675 212.67148]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [

# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# [ -98.28949  -134.87787    18.365334]
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning BULGE Velocities
# [ -82.43086 -211.4032  -109.62547]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -62.519444 -261.93445   -68.16612 ]
# Returning DM    Positions
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -79.9922  -225.7152  -100.97021]
# [ -75.628136 -241.65883  -113.25822 ]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Positions
# [ -67.63232 -236.50868 -114.45553]
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -97.41212  -142.54521    14.913687]
# [ -60.77797 -263.81262  -52.67714]
# [ -59.026474 -263.05948   -38.064964]
# [ -59.47947  -259.5858    -22.191711]
# [ -62.690502  -250.07784     -6.3599157]
# [ -96.122406 -150.98936    10.723856]
# [ -67.58509 -248.09595  -89.99381]
# [ -72.27309   -232.6596       1.7483114]
# [ -82.782104  -221.30977     -7.2931175]
# [ -94.92458  -160.40707     6.050483]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions[ -85.64622  -224.83441   -15.436646]
#
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -65.25305 -268.34775  -85.79041]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -64.86977  -259.85318   -62.120407]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -93.10231   -172.03421      0.3690698]
# [ -90.88169  -183.96939    -5.777371]
# [ -83.68391  -235.1166    -20.397532]
# [ -87.63792  -198.04231   -12.646194]
# [ -82.72137  -215.93475   -19.074652]
# [ -77.798836 -250.10036   -21.766308]
# [ -73.681885 -239.40657   -20.405777]
# [ -58.34101  -262.878     -55.513012]
# [ -60.714222 -264.75995   -37.739414]
# [ -63.07304 -259.25275   -8.04237]
# [ -58.474117  -268.75357      1.3452429]
# Returning DM    Positions
# [ -61.60229  -259.91324   -18.445087]
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -60.947178  -249.14099     -1.7448059]
# [ -67.2448   -270.8868    -15.812868]
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-7.2067413e+01 -2.3592482e+02  2.6754076e-02]
# Returning BULGE Velocities
# Returning DM    Positions
# [ -82.68117  -221.11127    -9.035767]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -85.037125 -226.75935   -18.041677]
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -57.016678  -273.27332      6.5132647]
# [ -58.78022   -285.02496      6.7348504]
# [ -60.295383  -285.81143      7.6326013]
# [ -54.38573  -305.73346     4.428517]
# [ -57.571358 -275.9084      8.943009]
# [ -56.640724  -297.12195      2.5184484]
# [ -52.066586  -313.8596       6.1810036]
# [ -84.00357  -234.52272   -19.012903]
# [ -50.088493 -321.82605     8.819619]
# Returning DM    Positions
# [ -60.206615 -276.2943      7.506939]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -48.21885  -329.3986     11.469111]
# Returning BULGE Velocities
# [ -77.21683 -249.93471  -23.42588]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -66.78422  -270.91522   -14.899034]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -57.28643  -292.76657    -3.306534]
# [ -61.79069  -281.1489     -4.741552]
# [ -46.457817 -336.93506    14.158834]
# [ -54.317413  -306.0181       4.8917627]
# [ -55.816486  -298.80692      2.7424352]
# [ -44.536324 -344.22647    15.989645]
# [ -60.255154  -286.03793      6.3431506]
# [ -52.13618  -313.9518      6.097944]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# [ -58.32728  -284.90518     8.656405]
# [ -50.275696 -321.54367     8.525106]
# Returning BULGE Velocities
# [ -48.136543 -329.51367    11.043669]
# Returning DM    Positions
# Returning DM    Particle IDs
# [ -53.83969  -305.84732     4.831407]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -42.895374 -351.84564    18.566248]
# [ -56.90821   -298.10956      3.7857401]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities[ -53.438656 -313.28256     6.875129]
#
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# [ -50.487663 -322.11856     9.185818]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -47.963387  -329.81073     12.2431345]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# [ -40.959007 -359.29672    20.91538 ]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -46.274128 -337.2829     14.196509]
# [ -38.94989  -367.3044     23.356834]
# [ -44.566044 -344.3034     16.440327]
# [ -36.952103 -374.91876    25.350039]
# [ -35.140167 -382.5647     27.732395]
# [ -33.270386 -389.7395     29.705462]
# [ -46.134438 -337.2459     13.708042]
# [ -31.448818 -398.00372    31.529726]
# [ -42.722637 -351.93372    18.31777 ]
# [ -29.600073 -405.46967    33.510742]
# [ -45.042698 -344.56186    15.995903]
# [ -42.116657 -351.62537    19.231102]
# [ -40.804005 -359.5126     21.050406]
# [ -38.79533  -367.28522    22.663157]
# [ -36.881466 -375.2204     25.342852]
# [ -40.856644 -358.85693    20.877157]
# [ -35.02026  -382.71066    27.985897]
# [ -33.310143 -389.86533    29.032734]
# [ -38.62249  -367.45062    23.660479]
# [ -31.42516  -398.0215     31.489407]
# [ -29.821836 -405.35757    33.497726]
# [ -36.93931  -375.07062    26.548637]
# [ -35.096043 -382.59262    26.967085]
# [ -32.981216 -390.16962    30.11826 ]
# [ -30.706804 -397.83188    30.741999]
# [ -29.816895 -404.99384    33.741703]

# %%
plt.plot(rCOM_mw[:, 0], rCOM_mw[:, 1], 'b-', label='MW')
plt.plot(rCOM_m31[:, 0], rCOM_m31[:, 1], 'r-', label='M31')
plt.plot(rCOM_lmc[:, 0], rCOM_lmc[:, 1], 'g-', label='LMC')
plt.legend()
plt.xlabel('x [kpc]')
plt.ylabel('y [kpc]')
plt.title('COM position')
plt.xlim(-500, 450)
plt.ylim(-450, 450)

plt.show()

# %%
fig, ax = plt.subplots()
def update(frame):
    # 清除子图
    ax.clear()
    ax.plot(rCOM_mw[:, 0], rCOM_mw[:, 1], 'b-', label='MW')
    ax.plot(rCOM_m31[:, 0], rCOM_m31[:, 1], 'r-', label='M31')
    ax.plot(rCOM_lmc[:, 0], rCOM_lmc[:, 1], 'g-', label='lmc')
    ax.scatter(rCOM_mw[frame, 0], rCOM_mw[frame, 1], c='b')
    ax.scatter(rCOM_m31[frame, 0], rCOM_m31[frame, 1], c='r')
    ax.scatter(rCOM_lmc[frame, 0], rCOM_lmc[frame, 1], c='g')
    ax.legend(fontsize=14)
    ax.set_xlabel('x [kpc]',fontsize=14)
    ax.set_ylabel('y [kpc]',fontsize=14)
    ax.set_title('COM position')
    ax.set_xlim(-500, 450)
    ax.set_ylim(-450, 450)
    ax.set_xticklabels(ax.get_xticks(), fontsize=10)
    ax.set_yticklabels(ax.get_yticks(), fontsize=10)
ani = FuncAnimation(fig, update, frames=len(rCOM_mw),  repeat=False)

# 保存动画为 GIF
ani.save('com_position_LMC.gif', writer='pillow', fps=10)

# 在 Jupyter Notebook 中显示动画
plt.show()
# Out:
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), fontsize=10)
# /tmp/ipykernel_865609/3338876996.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticks(), fontsize=10)

# %%
r_light_lmc = np.load('r_values_light_LMC.npz')
print(r_light_lmc.files)
r_values = r_light_lmc['arr_0']
print(r_values.shape)
# Out:
# ['arr_0']
# (70,)

# %%
r_nom33=np.load('r_values.npz.npy')
r_m33 = np.load('r_values_m33.npz.npy')

frames = np.arange(0,500, 5)
# 并行读取数据
results = Parallel(n_jobs=10)(delayed(read)(runpath, i) for i in frames)
r_values = np.array([np.linalg.norm(r_mw_m31) for posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc in results])
r_lmc_values = np.array([np.linalg.norm(r_mw_lmc) for posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc in results])
time_values = frames/50
plt.plot(time_values, r_values,label='with LMC')
#plt.plot(time_values, r_light_lmc,label='light LMC')
#plt.plot(time_values, r_heavy_lmc,label='heavy LMC')
plt.plot(time_values,r_nom33,label='only M31')
plt.plot(time_values,r_m33,label='with M33')
#plt.plot(time_values,r_lmc_values,label='with LMC')
plt.legend(fontsize=14)
plt.xlabel('Time [Gyr]', fontsize=16)
plt.ylabel('r [kpc]', fontsize=16)
plt.xlim(0,10)
plt.ylim(0,800)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DM    Positions
# Returning DM    Positions
# Returning DM    Positions
# Returning DISK  Positions
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning BULGE Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning DISK  Particle IDs
# Returning BULGE Positions
# Returning BULGE Particle IDs
# Returning DM    Positions
# Returning DISK  Positions
# Returning DISK  Particle IDs
# Returning BULGE Velocities
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning BULGE Velocities
# Returning BULGE Positions
# Returning DM    Positions
# Returning DISK  Positions
# Returning DM    Positions
# Returning DISK  Particle IDs
# Returning BULGE Positions
# Returning BULGE Particle IDs
# Returning DM    Particle IDs
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning DISK  Positions
# Returning DISK  Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning BULGE Particle IDs
# Returning BULGE Positions
# Returning BULGE Positions
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning DISK  Particle IDs
# Returning DISK  Positions
# Returning BULGE Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Positions
# Returning BULGE Velocities
# Returning BULGE Velocities
# Returning BULGE Velocities
# Returning DISK  Particle IDs
# Returning DISK  Positions
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Positions
# Returning BULGE Particle IDs
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning BULGE Velocities
# [-0.24279194 -2.3552134  -0.8453931 ]
# [ -3.932713  -15.275603    0.9135312]
# [ 0.03325323 -0.66739184 -0.47317925]
# [-0.7951699 -4.754124  -0.9829924]
# [ -6.223299  -19.91488     2.6808846]
# [-1.396788  -7.2963195 -0.8860831]
# [-0.0021618  -0.00543999  0.00177899]
# [ -3.0675495  -12.486378     0.03164109]
# [-2.1390166 -9.856515  -0.5366774]
# [ -4.978184  -17.742336    1.7396134]
# [-367.86285  582.7901  -275.97025]
# [-348.19574  522.98096 -267.62866]
# [-371.59595  594.05    -277.3235 ]
# [-375.13028  605.5266  -278.83322]

# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -58.474117  -268.75357      1.3452429][ -63.07304 -259.25275   -8.04237]
#
# [ -65.25305 -268.34775  -85.79041]
# [ -64.86977  -259.85318   -62.120407]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -58.34101  -262.878     -55.513012]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# [ -60.714222 -264.75995   -37.739414]
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -61.60229  -259.91324   -18.445087]
# [ -60.947178  -249.14099     -1.7448059]
# [-7.2067413e+01 -2.3592482e+02  2.6754076e-02]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -82.68117  -221.11127    -9.035767]
# Returning DM    Positions
# [ -85.037125 -226.75935   -18.041677]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -83.68391  -235.1166    -20.397532]
# [ -77.798836 -250.10036   -21.766308]
# [ -67.2448   -270.8868    -15.812868]
# [ -58.78022   -285.02496      6.7348504]
# [ -60.295383  -285.81143      7.6326013]
# [ -56.640724  -297.12195      2.5184484]
# [ -54.38573  -305.73346     4.428517]
# [ -52.066586  -313.8596       6.1810036]
# [ -50.088493 -321.82605     8.819619]
# [ -48.21885  -329.3986     11.469111]
# [ -57.016678  -273.27332      6.5132647]
# [ -61.79069  -281.1489     -4.741552]
# [ -60.206615 -276.2943      7.506939]
# [ -57.571358 -275.9084      8.943009]
# [ -57.28643  -292.76657    -3.306534]
# [ -55.816486  -298.80692      2.7424352]
# [ -84.00357  -234.52272   -19.012903]
# [ -52.13618  -313.9518      6.097944]
# Returning DM    Positions
# [ -50.275696 -321.54367     8.525106]
# [ -54.317413  -306.0181       4.8917627]
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -48.136543 -329.51367    11.043669]
# [ -58.32728  -284.90518     8.656405]
# [ -66.78422  -270.91522   -14.899034]
# [ -60.255154  -286.03793      6.3431506]
# [ -77.21683 -249.93471  -23.42588]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -56.90821   -298.10956      3.7857401]
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -53.438656 -313.28256     6.875129]
# [ -50.487663 -322.11856     9.185818]
# [ -53.83969  -305.84732     4.831407]
# Returning DM    Positions
# Returning DM    Particle IDs
# [ -47.963387  -329.81073     12.2431345]
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning DM    Positions
# Returning BULGE Velocities
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [ -46.457817 -336.93506    14.158834]
# [ -44.536324 -344.22647    15.989645]
# [ -40.959007 -359.29672    20.91538 ]
# [ -42.895374 -351.84564    18.566248]
# [ -38.94989  -367.3044     23.356834]
# [ -36.952103 -374.91876    25.350039]
# [ -35.140167 -382.5647     27.732395]
# [ -31.448818 -398.00372    31.529726]
# [ -33.270386 -389.7395     29.705462]
# [ -29.600073 -405.46967    33.510742]
# [ -46.274128 -337.2829     14.196509]
# [ -44.566044 -344.3034     16.440327]
# [ -40.804005 -359.5126     21.050406]
# [ -42.722637 -351.93372    18.31777 ]
# [ -38.79533  -367.28522    22.663157]
# [ -35.02026  -382.71066    27.985897]
# [ -46.134438 -337.2459     13.708042]
# [ -36.881466 -375.2204     25.342852]
# [ -31.42516  -398.0215     31.489407]
# [ -33.310143 -389.86533    29.032734]
# [ -29.821836 -405.35757    33.497726]
# [ -45.042698 -344.56186    15.995903]
# [ -40.856644 -358.85693    20.877157]
# [ -38.62249  -367.45062    23.660479]
# [ -42.116657 -351.62537    19.231102]
# [ -35.096043 -382.59262    26.967085]
# [ -30.706804 -397.83188    30.741999]
# [ -32.981216 -390.16962    30.11826 ]
# [ -36.93931  -375.07062    26.548637]
# [ -29.816895 -404.99384    33.741703]
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 100.0, '100'),
#   Text(0, 200.0, '200'),
#   Text(0, 300.0, '300'),
#   Text(0, 400.0, '400'),
#   Text(0, 500.0, '500'),
#   Text(0, 600.0, '600'),
#   Text(0, 700.0, '700'),
#   Text(0, 800.0, '800')])

# %%
#np.savez('r_values_light_LMC.npz', r_values)

# %%
r_light_lmc = np.load('r_values_light_LMC.npz')
r_heavy_lmc = np.load('r_values_heavy_LMC.npz')
MW_M31_light = r_light_lmc['r_values']
MW_LMC_light = r_light_lmc['r_lmc_values']
MW_M31_heavy = r_heavy_lmc['r_values']
MW_LMC_heavy = r_heavy_lmc['r_lmc_values']



r_values = np.array([np.linalg.norm(r_mw_m31) for posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc in results])
r_lmc_values = np.array([np.linalg.norm(r_mw_lmc) for posMW, posM31,posLMC,r_mw_m31,r_mw_lmc,r_m31_lmc in results])
time_values = frames/50

plt.plot(time_values, MW_M31_light,label='MW-M31-light',color='b')
plt.plot(time_values,MW_LMC_light,label='MW-LMC-light',color='b',linestyle='--')
plt.plot(time_values, r_values,label='MW-M31-mid',color='r')
plt.plot(time_values,r_lmc_values,label='MW-LMC-mid',color='r',linestyle='--')
plt.plot(time_values, MW_M31_heavy,label='MW-M31-heavy',color='g')
plt.plot(time_values,MW_LMC_heavy,label='MW-LMC-heavy',color='g',linestyle='--')
plt.legend(fontsize=14)
plt.xlim(0,10)
plt.ylim(0,800)
plt.xlabel('Time [Gyr]', fontsize=14)
plt.ylabel('r [kpc]', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700., 800.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 100.0, '100'),
#   Text(0, 200.0, '200'),
#   Text(0, 300.0, '300'),
#   Text(0, 400.0, '400'),
#   Text(0, 500.0, '500'),
#   Text(0, 600.0, '600'),
#   Text(0, 700.0, '700'),
#   Text(0, 800.0, '800')])

# %%
#np.savez('r_values_heavy_LMC.npz', r_values = r_values, r_lmc_values = r_lmc_values)

# %%
runpath = '/home/guozx/M31/Output/merge/'
frames = np.arange(0, 10, 10)

# 并行读取数据
results = Parallel(n_jobs=2)(delayed(read)(runpath, i) for i in frames)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))

r_values = [np.linalg.norm(result[4]) for result in results]
time_values = list(frames/50)
def update(frame):
    posdm_MW,posdm_M31,posMW, posM31,r = results[frame]
    
    # 清除子图
    for ax in axs.flat:
        ax.clear()
    
    # 绘制 x-y 图
    axs[0, 0].scatter(posMW[:,0], posMW[:,1], s=0.1, c='b', label='MW')
    axs[0, 0].scatter(posM31[:,0], posM31[:,1], s=0.1, c='r', label='M31')
    axs[0, 0].set_xlabel('x[kpc]')
    axs[0, 0].set_ylabel('y[kpc]')
    axs[0, 0].legend()
    axs[0, 0].set_xlim(-500, 500)
    axs[0, 0].set_ylim(-500, 500)
    
    # 绘制 x-z 图
    axs[1, 0].scatter(posMW[:,0], posMW[:,2], s=0.1, c='b', label='MW')
    axs[1, 0].scatter(posM31[:,0], posM31[:,2], s=0.1, c='r', label='M31')
    axs[1, 0].set_xlabel('x[kpc]')
    axs[1, 0].set_ylabel('z[kpc]')
    axs[1, 0].legend()
    axs[1, 0].set_xlim(-500, 500)
    axs[1, 0].set_ylim(-500, 500)
    
    # 绘制 y-z 图
    axs[1, 1].scatter(posMW[:,1], posMW[:,2], s=0.1, c='b', label='MW')
    axs[1, 1].scatter(posM31[:,1], posM31[:,2], s=0.1, c='r', label='M31')
    axs[1, 1].set_xlabel('y[kpc]')
    axs[1, 1].set_ylabel('z[kpc]')
    axs[1, 1].legend()
    axs[1, 1].set_xlim(-500, 500)
    axs[1, 1].set_ylim(-500, 500)
    
    # 绘制 r 随时间变化的图
    axs[0, 1].plot(time_values[:frame+1], r_values[:frame+1], 'g-')
    axs[0, 1].set_xlabel('Time')
    axs[0, 1].set_ylabel('r')
    axs[0, 1].set_title('r vs Time')
    axs[0, 1].set_xlim(0, 10)
    axs[0, 1].set_ylim(0, 800)
    
ani = FuncAnimation(fig, update, frames=len(frames), repeat=False)

# 保存动画
#ani.save('m31_vs_mw_animation.gif', writer=PillowWriter(fps=5))

# 在 Jupyter Notebook 中显示动画
HTML(ani.to_jshtml())
# Out:
# Returning DM    Positions
# Returning DM    Particle IDs
# Returning DISK  Positions
# Returning BULGE Positions
# Returning DISK  Particle IDs
# Returning BULGE Particle IDs
# Returning BULGE Velocities
# [-0.00039104  0.00064812  0.00128763]
# /tmp/ipykernel_3802381/1421523172.py:59: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   HTML(ani.to_jshtml())
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4d3915a5855140df9155e65d9ca87521">
#   <div class="anim-controls">
#     <input id="_anim_slider4d3915a5855140df9155e65d9ca87521" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4d3915a5855140df9155e65d9ca87521.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim4d3915a5855140df9155e65d9ca87521.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim4d3915a5855140df9155e65d9ca87521.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim4d3915a5855140df9155e65d9ca87521.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim4d3915a5855140df9155e65d9ca87521.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim4d3915a5855140df9155e65d9ca87521.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim4d3915a5855140df9155e65d9ca87521.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim4d3915a5855140df9155e65d9ca87521.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim4d3915a5855140df9155e65d9ca87521.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim4d3915a5855140df9155e65d9ca87521.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select4d3915a5855140df9155e65d9ca87521"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4d3915a5855140df9155e65d9ca87521"
#              checked>
#       <label for="_anim_radio1_4d3915a5855140df9155e65d9ca87521">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4d3915a5855140df9155e65d9ca87521"
#              >
#       <label for="_anim_radio2_4d3915a5855140df9155e65d9ca87521">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4d3915a5855140df9155e65d9ca87521"
#              >
#       <label for="_anim_radio3_4d3915a5855140df9155e65d9ca87521">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4d3915a5855140df9155e65d9ca87521";
#     var slider_id = "_anim_slider4d3915a5855140df9155e65d9ca87521";
#     var loop_select_id = "_anim_loop_select4d3915a5855140df9155e65d9ca87521";
#     var frames = new Array(1);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjkuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8hTgPZAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAACX5klEQV
# /home/guozx/anaconda3/lib/python3.12/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/guozx/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
10**(24.67/5+1)
# Out:
# 859013.521505396

# %%
(-384.2947991929431+515.3384350)**2+ ( 620.6460-531.2805467)**2+(285.798-445.348)**2
# Out:
# 50614.82122904705

# %%
-384.2947991929431 kpc 620.6460214974461 kpc -285.79823559569974

# %%
(50614)**0.5
# Out:
# 224.9755542275649
